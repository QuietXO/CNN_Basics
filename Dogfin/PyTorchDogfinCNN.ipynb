# %% [markdown]
# # **_Chihuahua vs. Muffin Classification_**
#
# ### __*This CNN is supposed to determine between a Chihuahua & a Muffin is in the Image*__

# %% [markdown]
# <br>
#
# ### __*Import Libraries and choose the device*__

# %%
# Import of the Libraries
import os
import csv
import numpy as np
import pandas as pd
import random as rand
import skimage
import matplotlib.pyplot as plt

# Torch libraries
import torch
import torchvision
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# Device config (Pick your set-up)
# GPU = torch.device('cpu')  # CPU
GPU = torch.device('cuda' if torch.cuda.is_available() else 'cpu')  # NVIDIA GPUs
# GPU = torch.device('mps' if torch.has_mps else 'cpu')  # ARM GPUs (M1, M2, ...)
print('Using the Processor') if GPU == torch.device('cpu') else print('Using the Graphics Card')
# Out:
# Using the Graphics Card

# %% [markdown]
# <br>
#
# ### __*Create the .csv file for Dataset*__

# %%
def create_csv( file_path, csv_path=False, train_csv=False, test_csv=False, rewrite=False, split=False, test_ratio=0.2, mul=1, mul_test=False):
    translate = dict()                                  # Class : Number
    categories = os.listdir(file_path)                  # Load all categories

    # Create an indexing dictionary
    for idx in range(len(categories)):
        translate[categories[idx]] = idx


    # Create one csv file
    if not split:
        if csv_path and not os.path.exists(csv_path) or rewrite:
            file = open(csv_path, 'w', newline='')      # Create the csv file
            writer = csv.writer(file)                   # Create a writer for csv file

            # Create a .csv file of all images & their class
            for idx in range(len(categories)):
                tmp_path = os.path.join(file_path, categories[idx])  # File path + Sub-File
                tmp_images = os.listdir(tmp_path)
                for img in tmp_images:
                    img_path = os.path.join(categories[idx], img)  # Sub-File + img
                    for _ in range(mul):                # Expand the dataset
                        writer.writerow((img_path, idx))
            file.close()                                # Close the file


    # Create train & test csv file
    if split:
        if (train_csv and test_csv) and (not os.path.exists(train_csv) or not os.path.exists(test_csv) or rewrite):
            train_f = open(train_csv, 'w', newline='')  # Create the train csv file
            test_f = open(test_csv, 'w', newline='')    # Create the test csv file
            train_writer = csv.writer(train_f)          # Create a writer for train csv file
            test_writer = csv.writer(test_f)            # Create a writer for test csv file

            # Create the .csv files of all images & their class
            for idx in range(len(categories)):
                tmp_path = os.path.join(file_path, categories[idx])
                tmp_images = os.listdir(tmp_path)
                test_split = int(len(tmp_images) / 100 * (test_ratio * 100))
                rand_dir = sorted(rand.sample(range(0, len(tmp_images)), test_split))
                train_idx = 0
                for img in tmp_images:
                    img_path = os.path.join(categories[idx], img)
                    if train_idx in rand_dir and mul_test:
                        for _ in range(mul):
                            test_writer.writerow((img_path, idx))
                    elif train_idx in rand_dir:
                        test_writer.writerow((img_path, idx))
                    else:
                        for _ in range(mul):
                            train_writer.writerow((img_path, idx))
                    train_idx += 1
            train_f.close()                             # Close the file
            test_f.close()                              # Close the file

    return translate

# %% [markdown]
# <br>
#
# ### __*Convert the Images into a Dataset*__

# %%
class DogfinDataset(Dataset):

    def __init__(self, file_path, csv_path, transform=None):
        self.annotations = pd.read_csv(csv_path)
        self.file_path = file_path
        self.transform = transform

    def __len__(self):
        return len(self.annotations)

    def __getitem__(self, index):
        img_path = os.path.join(self.file_path, self.annotations.iloc[index, 0])
        image = skimage.io.imread(img_path)
        y_label = torch.tensor(self.annotations.iloc[index, 1])

        if self.transform:
            image = self.transform(image)

        return image, y_label

# %% [markdown]
# <br>
#
# ### __*Convolutional Neural Network*__

# %%
class ConvNet(nn.Module):
    def __init__(self, colour, n_categories):
        super(ConvNet, self).__init__()
        # input = 3 colour channels, output = 6 (our choice), filter = 4*4 (our choice)
        self.conv1 = nn.Conv2d(colour, 6, 4)
        self.pool = nn.MaxPool2d(2, 2)  # take 2*2, then move 2 px
        # input = 6 channels (last output), output = 16 (our choice), filter = 4*4 (our choice)
        self.conv2 = nn.Conv2d(6, 16, 4)
        self.fc1 = nn.Linear(16 * 19 * 19, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, n_categories)


    def forward(self, x):
        # -> n, 3, 85, 85
        x = self.pool(torch.nn.functional.relu(self.conv1(x)))  # -> n, 6, 14, 14
        x = self.pool(torch.nn.functional.relu(self.conv2(x)))  # -> n, 16, 5, 5
        x = x.view(-1, 16 * 19 * 19)                            # -> n, 400
        x = torch.nn.functional.relu(self.fc1(x))               # -> n, 120
        x = torch.nn.functional.relu(self.fc2(x))               # -> n, 84
        x = self.fc3(x)                                         # -> n, 10
        return x

# %% [markdown]
# <br>
#
# ### __*Training Preparation (Set all variables here)*__

# %%
# Hyper-parameters
num_epochs = 15          # How many times to repeat learning
batch_size = 64          # Number of images to send at once
learning_rate = 0.001    # How quickly should it learn
steps_per_epoch = 5      # Number of prints per epoch

# Image Dimensions
IMG_SIZE = 85  # 85*85 pixels

# Define the directory
TRAIN_PATH = 'D:/datasets/dogfin/train'     # Sub-Folders Location
TEST_PATH = 'D:/datasets/dogfin/test'       # Sub-Folders Location
TRAIN_CSV = './data/dogfin/train_data.csv'  # Train CSV Location
TEST_CSV = './data/dogfin/test_data.csv'    # Test CSV Location
CATEGORIES = os.listdir(TRAIN_PATH)         # Turn Sub-Folder names into a list
N_CLASSES = len(CATEGORIES)                 # Number of different classes


# Transformation
# print(MEAN, STD)  # tensor(0.6042) tensor(0.2962) | tensor(0.6027) tensor(0.2950)
transformer = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Resize((IMG_SIZE, IMG_SIZE)),
    torchvision.transforms.RandomHorizontalFlip(),
    torchvision.transforms.RandomVerticalFlip(),
    torchvision.transforms.Grayscale(),
    torchvision.transforms.Normalize(0.60345, 0.2956)
])

# Create the .csv file & dictionary
create_csv(TRAIN_PATH, TRAIN_CSV, rewrite=True)
create_csv(TEST_PATH, TEST_CSV, rewrite=True)

# Create the Datasets
train_dataset = DogfinDataset(TRAIN_PATH, TRAIN_CSV, transform=transformer)
test_dataset = DogfinDataset(TEST_PATH, TEST_CSV, transform=transformer)

# Create the DataLoaders
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size)

# Create the Model
model = ConvNet(1, N_CLASSES).to(GPU)

# Choose type of Loss & Optimization function
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adamax(model.parameters(), lr=learning_rate)

# %% [markdown]
# #### __*Look at some data*__

# %%
def imshow(img):
    img = img / 2 + 0.5  # un-normalize
    np_img = img.numpy()
    plt.imshow(np.transpose(np_img, (1, 2, 0)))
    plt.show()


# Get some random training images
dataiter = iter(train_loader)
images, labels = next(dataiter)
print(images.shape)

# Show images
imshow(torchvision.utils.make_grid(images))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([64, 1, 85, 85])

# %% [markdown]
# <br>
#
# ### __*Training Loop (Works Automatically)*__

# %%
# Variables for epoch print
n_total_steps = len(train_loader)
mean_loss = 0

for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        # Origin shape: [4, 3, 32, 32] = 4, 3, 1024
        # input_layer: 3 input channels, 6 output channels, 5 kernel size
        images = images.to(GPU)
        labels = labels.to(GPU)

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        mean_loss += loss.item()

        # Backward & optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (i+1) % int(n_total_steps / steps_per_epoch) == 0:
            print(f'Epoch {epoch + 1} / {num_epochs} | Step {i+1} / {n_total_steps} | '
                  f'Loss: {(mean_loss/2000):.4f}')
            mean_loss = 0

print('--- Training Finished ---')
SAVE_PATH = './dogfin.pth'
torch.save(model.state_dict(), SAVE_PATH)

with torch.no_grad():
    n_correct = 0
    n_samples = 0
    n_class_correct = [0 for i in range(N_CLASSES)]
    n_class_samples = [0 for i in range(N_CLASSES)]
    for images, labels in test_loader:
        images = images.to(GPU)
        labels = labels.to(GPU)
        outputs = model(images)
        # max returns (value ,index)
        _, predicted = torch.max(outputs, 1)
        n_samples += labels.size(0)
        n_correct += (predicted == labels).sum().item()

        for i in range(len(labels)):
            label = labels[i]
            pred = predicted[i]
            if label == pred:
                n_class_correct[label] += 1
            n_class_samples[label] += 1


    accuracy = 100.0 * n_correct / n_samples
    print(f'Accuracy of the Model: {accuracy:.2f} %')

    for i in range(N_CLASSES):
        accuracy = 100.0 * n_class_correct[i] / n_class_samples[i]
        print(f'Accuracy of {CATEGORIES[i]}: {accuracy:.2f} %')
# Out:
# Epoch 1 / 15 | Step 14 / 74 | Loss: 0.0046
# Epoch 1 / 15 | Step 28 / 74 | Loss: 0.0043
# Epoch 1 / 15 | Step 42 / 74 | Loss: 0.0043
# Epoch 1 / 15 | Step 56 / 74 | Loss: 0.0040
# Epoch 1 / 15 | Step 70 / 74 | Loss: 0.0038
# Epoch 2 / 15 | Step 14 / 74 | Loss: 0.0046
# Epoch 2 / 15 | Step 28 / 74 | Loss: 0.0038
# Epoch 2 / 15 | Step 42 / 74 | Loss: 0.0036
# Epoch 2 / 15 | Step 56 / 74 | Loss: 0.0034
# Epoch 2 / 15 | Step 70 / 74 | Loss: 0.0036
# Epoch 3 / 15 | Step 14 / 74 | Loss: 0.0044
# Epoch 3 / 15 | Step 28 / 74 | Loss: 0.0035
# Epoch 3 / 15 | Step 42 / 74 | Loss: 0.0032
# Epoch 3 / 15 | Step 56 / 74 | Loss: 0.0030
# Epoch 3 / 15 | Step 70 / 74 | Loss: 0.0033
# Epoch 4 / 15 | Step 14 / 74 | Loss: 0.0039
# Epoch 4 / 15 | Step 28 / 74 | Loss: 0.0029
# Epoch 4 / 15 | Step 42 / 74 | Loss: 0.0029
# Epoch 4 / 15 | Step 56 / 74 | Loss: 0.0030
# Epoch 4 / 15 | Step 70 / 74 | Loss: 0.0031
# Epoch 5 / 15 | Step 14 / 74 | Loss: 0.0037
# Epoch 5 / 15 | Step 28 / 74 | Loss: 0.0027
# Epoch 5 / 15 | Step 42 / 74 | Loss: 0.0027
# Epoch 5 / 15 | Step 56 / 74 | Loss: 0.0027
# Epoch 5 / 15 | Step 70 / 74 | Loss: 0.0030
# Epoch 6 / 15 | Step 14 / 74 | Loss: 0.0034
# Epoch 6 / 15 | Step 28 / 74 | Loss: 0.0028
# Epoch 6 / 15 | Step 42 / 74 | Loss: 0.0025
# Epoch 6 / 15 | Step 56 / 74 | Loss: 0.0026
# Epoch 6 / 15 | Step 70 / 74 | Loss: 0.0027
# Epoch 7 / 15 | Step 14 / 74 | Loss: 0.0032
# Epoch 7 / 15 | Step 28 / 74 | Loss: 0.0026
# Epoch 7 / 15 | Step 42 / 74 | Loss: 0.0025
# Epoch 7 / 15 | Step 56 / 74 | Loss: 0.0025
# Epoch 7 / 15 | Step 70 / 74 | Loss: 0.0026
# Epoch 8 / 15 | Step 14 / 74 | Loss: 0.0033
# Epoch 8 / 15 | Step 28 / 74 | Loss: 0.0023
# Epoch 8 / 15 | Step 42 / 74 | Loss: 0.0023
# Epoch 8 / 15 | Step 56 / 74 | Loss: 0.0025
# Epoch 8 / 15 | Step 70 / 74 | Loss: 0.0026
# Epoch 9 / 15 | Step 14 / 74 | Loss: 0.0031
# Epoch 9 / 15 | Step 28 / 74 | Loss: 0.0021
# Epoch 9 / 15 | Step 42 / 74 | Loss: 0.0026
# Epoch 9 / 15 | Step 56 / 74 | Loss: 0.0022
# Epoch 9 / 15 | Step 70 / 74 | Loss: 0.0025
# Epoch 10 / 15 | Step 14 / 74 | Loss: 0.0030
# Epoch 10 / 15 | Step 28 / 74 | Loss: 0.0023
# Epoch 10 / 15 | Step 42 / 74 | Loss: 0.0022
# Epoch 10 / 15 | Step 56 / 74 | Loss: 0.0023
# Epoch 10 / 15 | Step 70 / 74 | Loss: 0.0022
# Epoch 11 / 15 | Step 14 / 74 | Loss: 0.0028
# Epoch 11 / 15 | Step 28 / 74 | Loss: 0.0025
# Epoch 11 / 15 | Step 42 / 74 | Loss: 0.0022
# Epoch 11 / 15 | Step 56 / 74 | Loss: 0.0023
# Epoch 11 / 15 | Step 70 / 74 | Loss: 0.0024
# Epoch 12 / 15 | Step 14 / 74 | Loss: 0.0028
# Epoch 12 / 15 | Step 28 / 74 | Loss: 0.0022
# Epoch 12 / 15 | Step 42 / 74 | Loss: 0.0022
# Epoch 12 / 15 | Step 56 / 74 | Loss: 0.0022
# Epoch 12 / 15 | Step 70 / 74 | Loss: 0.0022
# Epoch 13 / 15 | Step 14 / 74 | Loss: 0.0025
# Epoch 13 / 15 | Step 28 / 74 | Loss: 0.0021
# Epoch 13 / 15 | Step 42 / 74 | Loss: 0.0022
# Epoch 13 / 15 | Step 56 / 74 | Loss: 0.0023
# Epoch 13 / 15 | Step 70 / 74 | Loss: 0.0021
# Epoch 14 / 15 | Step 14 / 74 | Loss: 0.0028
# Epoch 14 / 15 | Step 28 / 74 | Loss: 0.0021
# Epoch 14 / 15 | Step 42 / 74 | Loss: 0.0020
# Epoch 14 / 15 | Step 56 / 74 | Loss: 0.0021
# Epoch 14 / 15 | Step 70 / 74 | Loss: 0.0019
# Epoch 15 / 15 | Step 14 / 74 | Loss: 0.0025
# Epoch 15 / 15 | Step 28 / 74 | Loss: 0.0020
# Epoch 15 / 15 | Step 42 / 74 | Loss: 0.0020
# Epoch 15 / 15 | Step 56 / 74 | Loss: 0.0018
# Epoch 15 / 15 | Step 70 / 74 | Loss: 0.0020
# --- Training Finished ---
# Accuracy of the Model: 82.25 %
# Accuracy of chihuahua: 92.02 %
# Accuracy of muffin: 70.77 %
